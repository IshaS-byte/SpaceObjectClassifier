# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import os
from sklearn.metrics import classification_report
from PIL import Image
import gc

# %%
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
tf.config.threading.set_intra_op_parallelism_threads(4)
tf.config.threading.set_inter_op_parallelism_threads(4)

# %%
train_dir = "./data/train"
test_dir = "./data/test"

# %%
IMG_SIZE = 64
BATCH_SIZE = 16
EPOCHS = 5

# %%
from pathlib import Path

def validate_and_clean_with_tensorflow(data_dir):
    """Remove images that TensorFlow cannot decode."""
    removed_files = []
    checked_count = 0
    
    print(f"\nValidating with TensorFlow: {data_dir}")
    
    # Get all image files
    image_extensions = ['.jpg', '.jpeg', '.png', '.gif', '.bmp', '.webp']
    all_files = []
    
    for root, dirs, files in os.walk(data_dir):
        for file in files:
            if any(file.lower().endswith(ext) for ext in image_extensions):
                all_files.append(os.path.join(root, file))
    
    print(f"Found {len(all_files)} image files to check")
    
    for file_path in all_files:
        try:
            # Try to load and decode exactly like TensorFlow does during training
            img_raw = tf.io.read_file(file_path)
            img = tf.image.decode_image(img_raw, channels=3, expand_animations=False)
            
            # Check if image has valid shape
            if len(img.shape) != 3 or img.shape[2] != 3:
                raise ValueError(f"Invalid shape: {img.shape}")
            
            checked_count += 1
            
            # Progress update
            if checked_count % 50 == 0:
                print(f"Validated {checked_count}/{len(all_files)} images...")
                
        except Exception as e:
            print(f"TensorFlow cannot decode: {os.path.basename(file_path)}")
            print(f"   Error: {str(e)[:80]}")
            try:
                os.remove(file_path)
                removed_files.append(file_path)
                print(f"   Removed successfully")
            except Exception as remove_error:
                print(f"   Could not remove: {remove_error}")
    
    print(f"\nTensorFlow validation complete!")
    print(f"  - Valid images: {checked_count}")
    print(f"  - Removed: {len(removed_files)}")
    
    return removed_files

# %%
# Clean the data
validate_and_clean_with_tensorflow(train_dir)
validate_and_clean_with_tensorflow(test_dir)
# Out:
# Validating with TensorFlow: ./data/train
# Found 92259 image files to check
# Validated 50/92259 images...
# Validated 100/92259 images...
# Validated 150/92259 images...
# Validated 200/92259 images...
# Validated 250/92259 images...
# Validated 300/92259 images...
# Validated 350/92259 images...
# Validated 400/92259 images...
# Validated 450/92259 images...
# Validated 500/92259 images...
# Validated 550/92259 images...
# Validated 600/92259 images...
# Validated 650/92259 images...
# Validated 700/92259 images...
# Validated 750/92259 images...
# Validated 800/92259 images...
# Validated 850/92259 images...
# Validated 900/92259 images...
# Validated 950/92259 images...
# Validated 1000/92259 images...
# Validated 1050/92259 images...
# Validated 1100/92259 images...
# Validated 1150/92259 images...
# Validated 1200/92259 images...
# Validated 1250/92259 images...
# Validated 1300/92259 images...
# Validated 1350/92259 images...
# Validated 1400/92259 images...
# Validated 1450/92259 images...
# Validated 1500/92259 images...
# Validated 1550/92259 images...
# Validated 1600/92259 images...
# Validated 1650/92259 images...
# Validated 1700/92259 images...
# Validated 1750/92259 images...
# Validated 1800/92259 images...
# Validated 1850/92259 images...
# Validated 1900/92259 images...
# Validated 1950/92259 images...
# Validated 2000/92259 images...
# Validated 2050/92259 images...
# Validated 2100/92259 images...
# Validated 2150/92259 images...
# Validated 2200/92259 images...
# Validated 2250/92259 images...
# Validated 2300/92259 images...
# Validated 2350/92259 images...
# Validated 2400/92259 images...
# Validated 2450/92259 images...
# Validated 2500/92259 images...
# Validated 2550/92259 images...
# Validated 2600/92259 images...
# Validated 2650/92259 images...
# Validated 2700/92259 images...
# Validated 2750/92259 images...
# Validated 2800/92259 images...
# Validated 2850/92259 images...
# Validated 2900/92259 images...
# Validated 2950/92259 images...
# Validated 3000/92259 images...
# Validated 3050/92259 images...
# Validated 3100/92259 images...
# Validated 3150/92259 images...
# Validated 3200/92259 images...
# Validated 3250/92259 images...
# Validated 3300/92259 images...
# Validated 3350/92259 images...
# Validated 3400/92259 images...
# Validated 3450/92259 images...
# Validated 3500/92259 images...
# Validated 3550/92259 images...
# Validated 3600/92259 images...
# Validated 3650/92259 images...
# Validated 3700/92259 images...
# Validated 3750/92259 images...
# Validated 3800/92259 images...
# Validated 3850/92259 images...
# Validated 3900/92259 images...
# Validated 3950/92259 images...
# Validated 4000/92259 images...
# Validated 4050/92259 images...
# Validated 4100/92259 images...
# Validated 4150/92259 images...
# Validated 4200/92259 images...
# Validated 4250/92259 images...
# Validated 4300/92259 images...
# Validated 4350/92259 images...
# Validated 4400/92259 images...
# Validated 4450/92259 images...
# Validated 4500/92259 images...
# Validated 4550/92259 images...
# Validated 4600/92259 images...
# Validated 4650/92259 images...
# Validated 4700/92259 images...
# Validated 4750/92259 images...
# Validated 4800/92259 images...
# Validated 4850/92259 images...
# Validated 4900/92259 images...
# Validated 4950/92259 images...
# Validated 5000/92259 images...
# Validated 5050/92259 images...
# Validated 5100/92259 images...
# Validated 5150/92259 images...
# Validated 5200/92259 images...
# Validated 5250/92259 images...
# Validated 5300/92259 images...
# Validated 5350/92259 images...
# Validated 5400/92259 images...
# Validated 5450/92259 images...
# Validated 5500/92259 images...
# Validated 5550/92259 images...
# Validated 5600/92259 images...
# Validated 5650/92259 images...
# Validated 5700/92259 images...
# Validated 5750/92259 images...
# Validated 5800/92259 images...
# Validated 5850/92259 images...
# Validated 5900/92259 images...
# Validated 5950/92259 images...
# Validated 6000/92259 images...
# Validated 6050/92259 images...
# Validated 6100/92259 images...
# Validated 6150/92259 images...
# Validated 6200/92259 images...
# Validated 6250/92259 images...
# Validated 6300/92259 images...
# Validated 6350/92259 images...
# Validated 6400/92259 images...
# Validated 6450/92259 images...
# Validated 6500/92259 images...
# Validated 6550/92259 images...
# Validated 6600/92259 images...
# Validated 6650/92259 images...
# Validated 6700/92259 images...
# Validated 6750/92259 images...
# Validated 6800/92259 images...
# Validated 6850/92259 images...
# Validated 6900/92259 images...
# Validated 6950/92259 images...
# Validated 7000/92259 images...
# Validated 7050/92259 images...
# Validated 7100/92259 images...
# Validated 7150/92259 images...
# Validated 7200/92259 images...
# Validated 7250/92259 images...
# Validated 7300/92259 images...
# Validated 7350/92259 images...
# Validated 7400/92259 images...
# Validated 7450/92259 images...
# Validated 7500/92259 images...
# Validated 7550/92259 images...
# Validated 89400/92259 images...
# Validated 89450/92259 images...
# Validated 89500/92259 images...
# Validated 89550/92259 images...
# Validated 89600/92259 images...
# Validated 89650/92259 images...
# Validated 89700/92259 images...
# Validated 89750/92259 images...
# Validated 89800/92259 images...
# Validated 89850/92259 images...
# Validated 89900/92259 images...
# Validated 89950/92259 images...
# Validated 90000/92259 images...
# Validated 90050/92259 images...
# Validated 90100/92259 images...
# Validated 90150/92259 images...
# Validated 90200/92259 images...
# Validated 90250/92259 images...
# Validated 90300/92259 images...
# Validated 90350/92259 images...
# Validated 90400/92259 images...
# Validated 90450/92259 images...
# Validated 90500/92259 images...
# Validated 90550/92259 images...
# Validated 90600/92259 images...
# Validated 90650/92259 images...
# Validated 90700/92259 images...
# Validated 90750/92259 images...
# Validated 90800/92259 images...
# Validated 90850/92259 images...
# Validated 90900/92259 images...
# Validated 90950/92259 images...
# Validated 91000/92259 images...
# Validated 91050/92259 images...
# Validated 91100/92259 images...
# Validated 91150/92259 images...
# Validated 91200/92259 images...
# Validated 91250/92259 images...
# Validated 91300/92259 images...
# Validated 91350/92259 images...
# Validated 91400/92259 images...
# Validated 91450/92259 images...
# Validated 91500/92259 images...
# Validated 91550/92259 images...
# Validated 91600/92259 images...
# Validated 91650/92259 images...
# Validated 91700/92259 images...
# Validated 91750/92259 images...
# Validated 91800/92259 images...
# Validated 91850/92259 images...
# Validated 91900/92259 images...
# Validated 91950/92259 images...
# Validated 92000/92259 images...
# Validated 92050/92259 images...
# Validated 92100/92259 images...
# Validated 92150/92259 images...
# Validated 92200/92259 images...
# Validated 92250/92259 images...
#
# TensorFlow validation complete!
#   - Valid images: 92259
#   - Removed: 0
#
# Validating with TensorFlow: ./data/test
# Found 2686 image files to check
# Validated 50/2686 images...
# Validated 100/2686 images...
# Validated 150/2686 images...
# Validated 200/2686 images...
# Validated 250/2686 images...
# Validated 300/2686 images...
# Validated 350/2686 images...
# Validated 400/2686 images...
# Validated 450/2686 images...
# Validated 500/2686 images...
# Validated 550/2686 images...
# Validated 600/2686 images...
# Validated 650/2686 images...
# Validated 700/2686 images...
# Validated 750/2686 images...
# Validated 800/2686 images...
# Validated 850/2686 images...
# Validated 900/2686 images...
# TensorFlow cannot decode: Nebula0849.jpg
#    Error: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/de
#    Removed successfully
# Validated 950/2686 images...
# Validated 1000/2686 images...
# Validated 1050/2686 images...
# Validated 1100/2686 images...
# Validated 1150/2686 images...
# Validated 1200/2686 images...
# Validated 1250/2686 images...
# TensorFlow cannot decode: Nebula1266.jpg
#    Error: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/de
#    Removed successfully
# Validated 1300/2686 images...
# Validated 1350/2686 images...
# TensorFlow cannot decode: Nebula1345.jpg
#    Error: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/de
#    Removed successfully
# Validated 1400/2686 images...
# TensorFlow cannot decode: Nebula1389.jpg
#    Error: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/de
#    Removed successfully
# Validated 1450/2686 images...
# Validated 1500/2686 images...
# Validated 1550/2686 images...
# Validated 1600/2686 images...
# Validated 1650/2686 images...
# Validated 1700/2686 images...
# Validated 1750/2686 images...
# Validated 1800/2686 images...
# Validated 1850/2686 images...
# Validated 1900/2686 images...
# Validated 1950/2686 images...
# Validated 2000/2686 images...
# Validated 2050/2686 images...
# Validated 2100/2686 images...
# Validated 2150/2686 images...
# Validated 2200/2686 images...
# Validated 2250/2686 images...
# Validated 2300/2686 images...
# Validated 2350/2686 images...
# Validated 2400/2686 images...
# Validated 2450/2686 images...
# Validated 2500/2686 images...
# Validated 2550/2686 images...
# Validated 2600/2686 images...
# Validated 2650/2686 images...
#
# TensorFlow validation complete!
#   - Valid images: 2682
#   - Removed: 4
# ['./data/test\\nebula\\Nebula0849.jpg',
#  './data/test\\nebula\\Nebula1266.jpg',
#  './data/test\\nebula\\Nebula1345.jpg',
#  './data/test\\nebula\\Nebula1389.jpg']

# %%
# load datasets
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=False
)

class_names = train_ds.class_names
num_classes = len(class_names)
print("\nClasses found:", class_names)
print(f"Number of classes: {num_classes}")
# Out:
# Found 92259 files belonging to 5 classes.
# Found 2682 files belonging to 5 classes.
#
# Classes found: ['galaxy', 'nebula', 'planet', 'star', 'unknown']
# Number of classes: 5

# %%
train_ds = train_ds.cache().prefetch(tf.data.AUTOTUNE)
test_ds = test_ds.cache().prefetch(tf.data.AUTOTUNE)

# %%
# Build models
model = models.Sequential([
    layers.Rescaling(1./255, input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    layers.Conv2D(16, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print(model.summary())
# Out:
# C:\Users\samriti\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\preprocessing\data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 64, 64, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 62, 62, 16)          │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 31, 31, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 29, 29, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 12, 12, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 6, 6, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2304)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │         147,520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │             325 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 171,429 (669.64 KB)
#  Trainable params: 171,429 (669.64 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# training
history = model.fit(
    train_ds, 
    validation_data=test_ds, 
    epochs=EPOCHS
)
# Out:
# Epoch 1/5
# 5767/5767 ━━━━━━━━━━━━━━━━━━━━ 156s 27ms/step - accuracy: 0.9894 - loss: 0.0357 - val_accuracy: 0.9139 - val_loss: 0.2894
# Epoch 2/5
# 5767/5767 ━━━━━━━━━━━━━━━━━━━━ 106s 18ms/step - accuracy: 0.9950 - loss: 0.0159 - val_accuracy: 0.9471 - val_loss: 0.1734
# Epoch 3/5
# 5767/5767 ━━━━━━━━━━━━━━━━━━━━ 78s 14ms/step - accuracy: 0.9965 - loss: 0.0111 - val_accuracy: 0.9508 - val_loss: 0.1586
# Epoch 4/5
# 5767/5767 ━━━━━━━━━━━━━━━━━━━━ 86s 15ms/step - accuracy: 0.9972 - loss: 0.0092 - val_accuracy: 0.9635 - val_loss: 0.1253
# Epoch 5/5
# 5767/5767 ━━━━━━━━━━━━━━━━━━━━ 82s 14ms/step - accuracy: 0.9979 - loss: 0.0069 - val_accuracy: 0.9090 - val_loss: 0.3589

# %%
# evaluation
test_loss, test_acc = model.evaluate(test_ds)
print(f"\nBaseline Test Accuracy: {round(test_acc * 100, 2)}%")
# Out:
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9090 - loss: 0.3589
#
# Baseline Test Accuracy: 90.9%

# %%
import numpy as np
y_true = []
y_pred = []

for images, labels in test_ds:
    preds = model.predict(images, verbose=0)
    pred_classes = np.argmax(preds, axis=1)
    y_true.extend(labels.numpy())
    y_pred.extend(pred_classes)

y_true = np.array(y_true)
y_pred = np.array(y_pred)

print("Model Performance Summary:")

overall_acc = (y_true == y_pred).sum() / len(y_true)
print(f"\nOverall Accuracy: {overall_acc * 100:.2f}%")

print(f"\nTotal samples: {len(y_true)}")

for i, class_name in enumerate(class_names):
    # Get samples for this class
    true_mask = y_true == i
    num_samples = true_mask.sum()
    
    if num_samples > 0:
        # Calculate accuracy for this class
        correct = ((y_true == i) & (y_pred == i)).sum()
        accuracy = correct / num_samples * 100
        
        print(f"\n{class_name}:")
        print(f"  Samples: {num_samples}")
        print(f"  Correct: {correct}")
        print(f"  Accuracy: {accuracy:.2f}%")

gc.collect()
# Out:
# Model Performance Summary:
#
# Overall Accuracy: 90.90%
#
# Total samples: 2682
#
# galaxy:
#   Samples: 108
#   Correct: 108
#   Accuracy: 100.00%
#
# nebula:
#   Samples: 1567
#   Correct: 1372
#   Accuracy: 87.56%
#
# planet:
#   Samples: 643
#   Correct: 632
#   Accuracy: 98.29%
#
# star:
#   Samples: 17
#   Correct: 0
#   Accuracy: 0.00%
#
# unknown:
#   Samples: 347
#   Correct: 326
#   Accuracy: 93.95%
# 3394

# %%
os.makedirs("results", exist_ok=True)

# Save a simpler report
with open("results/baseline_performance.txt", "w") as f:
    f.write("BASELINE MODEL PERFORMANCE\n")
    
    f.write(f"Test Accuracy: {round(test_acc * 100, 2)}%\n")
    f.write(f"Test Loss: {round(test_loss, 4)}\n\n")
    
    f.write("Classes:\n")
    for i, c in enumerate(class_names):
        f.write(f"  {i}: {c}\n")
    
    f.write("\n" + "=" * 60 + "\n")
    f.write("PER-CLASS PERFORMANCE\n")
    f.write("=" * 60 + "\n\n")
    
    # Manual per-class accuracy
    for i, class_name in enumerate(class_names):
        class_mask = y_true == i
        if class_mask.sum() > 0:
            correct = ((y_true == i) & (y_pred == i)).sum()
            total = class_mask.sum()
            accuracy = correct / total * 100
            f.write(f"{class_name}:\n")
            f.write(f"  Samples: {total}\n")
            f.write(f"  Correct: {correct}\n")
            f.write(f"  Accuracy: {accuracy:.2f}%\n\n")
    
    f.write("CONFIGURATION\n")
    f.write(f"Image Size: {IMG_SIZE}x{IMG_SIZE}\n")
    f.write(f"Batch Size: {BATCH_SIZE}\n")
    f.write(f"Epochs: {EPOCHS}\n")

print("Performance report saved")

# Save model
model.save("results/baseline_model.h5")
print("Model saved")

gc.collect()
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Performance report saved
# Model saved
# 0
