# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import os
from sklearn.metrics import classification_report
from PIL import Image
import gc

# %%
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
tf.config.threading.set_intra_op_parallelism_threads(4)
tf.config.threading.set_inter_op_parallelism_threads(4)
print("TensorFlow memory limits configured")
# Out:
# ✓ TensorFlow memory limits configured

# %%
train_dir = "data/train"
test_dir = "data/test"

# %%
IMG_SIZE = 64
BATCH_SIZE = 16
EPOCHS = 5

# %%
from pathlib import Path

def validate_and_clean_with_tensorflow(data_dir):
    """Remove images that TensorFlow cannot decode."""
    removed_files = []
    checked_count = 0
    
    print(f"\nValidating with TensorFlow: {data_dir}")
    
    # Get all image files
    image_extensions = ['.jpg', '.jpeg', '.png', '.gif', '.bmp', '.webp']
    all_files = []
    
    for root, dirs, files in os.walk(data_dir):
        for file in files:
            if any(file.lower().endswith(ext) for ext in image_extensions):
                all_files.append(os.path.join(root, file))
    
    print(f"Found {len(all_files)} image files to check")
    
    for file_path in all_files:
        try:
            # Try to load and decode exactly like TensorFlow does during training
            img_raw = tf.io.read_file(file_path)
            img = tf.image.decode_image(img_raw, channels=3, expand_animations=False)
            
            # Check if image has valid shape
            if len(img.shape) != 3 or img.shape[2] != 3:
                raise ValueError(f"Invalid shape: {img.shape}")
            
            checked_count += 1
            
            # Progress update
            if checked_count % 50 == 0:
                print(f"Validated {checked_count}/{len(all_files)} images...")
                
        except Exception as e:
            print(f"TensorFlow cannot decode: {os.path.basename(file_path)}")
            print(f"   Error: {str(e)[:80]}")
            try:
                os.remove(file_path)
                removed_files.append(file_path)
                print(f"   Removed successfully")
            except Exception as remove_error:
                print(f"   Could not remove: {remove_error}")
    
    print(f"\nTensorFlow validation complete!")
    print(f"  - Valid images: {checked_count}")
    print(f"  - Removed: {len(removed_files)}")
    
    return removed_files

# %%
# Clean the data
validate_and_clean_with_tensorflow(train_dir)
validate_and_clean_with_tensorflow(test_dir)
# Out:
# Validating with TensorFlow: data/train
# Found 30305 image files to check
# ✓ Validated 50/30305 images...
# ✓ Validated 100/30305 images...
# ✓ Validated 150/30305 images...
# ✓ Validated 200/30305 images...
# ✓ Validated 250/30305 images...
# ✓ Validated 300/30305 images...
# ✓ Validated 350/30305 images...
# ✓ Validated 400/30305 images...
# ✓ Validated 450/30305 images...
# ✓ Validated 500/30305 images...
# ✓ Validated 550/30305 images...
# ✓ Validated 600/30305 images...
# ✓ Validated 650/30305 images...
# ✓ Validated 700/30305 images...
# ✓ Validated 750/30305 images...
# ✓ Validated 800/30305 images...
# ✓ Validated 850/30305 images...
# ✓ Validated 900/30305 images...
# ✓ Validated 950/30305 images...
# ✓ Validated 1000/30305 images...
# ✓ Validated 1050/30305 images...
# ✓ Validated 1100/30305 images...
# ✓ Validated 1150/30305 images...
# ✓ Validated 1200/30305 images...
# ✓ Validated 1250/30305 images...
# ✓ Validated 1300/30305 images...
# ✓ Validated 1350/30305 images...
# ✓ Validated 1400/30305 images...
# ✓ Validated 1450/30305 images...
# ✓ Validated 1500/30305 images...
# ✓ Validated 1550/30305 images...
# ✓ Validated 1600/30305 images...
# ✓ Validated 1650/30305 images...
# ✓ Validated 1700/30305 images...
# ✓ Validated 1750/30305 images...
# ✓ Validated 1800/30305 images...
# ✓ Validated 1850/30305 images...
# ✓ Validated 1900/30305 images...
# ✓ Validated 1950/30305 images...
# ✓ Validated 2000/30305 images...
# ✓ Validated 2050/30305 images...
# ✓ Validated 2100/30305 images...
# ✓ Validated 2150/30305 images...
# ✓ Validated 2200/30305 images...
# ✓ Validated 2250/30305 images...
# ✓ Validated 2300/30305 images...
# ✓ Validated 2350/30305 images...
# ✓ Validated 2400/30305 images...
# ✓ Validated 2450/30305 images...
# ✓ Validated 2500/30305 images...
# ✓ Validated 2550/30305 images...
# ✓ Validated 2600/30305 images...
# ✓ Validated 2650/30305 images...
# ✓ Validated 2700/30305 images...
# ✓ Validated 2750/30305 images...
# ✓ Validated 2800/30305 images...
# ✓ Validated 2850/30305 images...
# ✓ Validated 2900/30305 images...
# ✓ Validated 2950/30305 images...
# ✓ Validated 3000/30305 images...
# ✓ Validated 3050/30305 images...
# ✓ Validated 3100/30305 images...
# ✓ Validated 3150/30305 images...
# ✓ Validated 3200/30305 images...
# ✓ Validated 3250/30305 images...
# ✓ Validated 3300/30305 images...
# ✓ Validated 3350/30305 images...
# ✓ Validated 3400/30305 images...
# ✓ Validated 3450/30305 images...
# ✓ Validated 3500/30305 images...
# ✓ Validated 3550/30305 images...
# ✓ Validated 3600/30305 images...
# ✓ Validated 3650/30305 images...
# ✓ Validated 3700/30305 images...
# ✓ Validated 3750/30305 images...
# ✓ Validated 3800/30305 images...
# ✓ Validated 3850/30305 images...
# ✓ Validated 3900/30305 images...
# ✓ Validated 3950/30305 images...
# ✓ Validated 4000/30305 images...
# ✓ Validated 4050/30305 images...
# ✓ Validated 4100/30305 images...
# ✓ Validated 4150/30305 images...
# ✓ Validated 4200/30305 images...
# ✓ Validated 4250/30305 images...
# ✓ Validated 4300/30305 images...
# ✓ Validated 4350/30305 images...
# ✓ Validated 4400/30305 images...
# ✓ Validated 4450/30305 images...
# ✓ Validated 4500/30305 images...
# ✓ Validated 4550/30305 images...
# ✓ Validated 4600/30305 images...
# ✓ Validated 4650/30305 images...
# ✓ Validated 4700/30305 images...
# ✓ Validated 4750/30305 images...
# ✓ Validated 4800/30305 images...
# ✓ Validated 4850/30305 images...
# ✓ Validated 4900/30305 images...
# ✓ Validated 4950/30305 images...
# ✓ Validated 5000/30305 images...
# ✓ Validated 5050/30305 images...
# ✓ Validated 5100/30305 images...
# ✓ Validated 5150/30305 images...
# ✓ Validated 5200/30305 images...
# ✓ Validated 5250/30305 images...
# ✓ Validated 5300/30305 images...
# ✓ Validated 5350/30305 images...
# ✓ Validated 5400/30305 images...
# ✓ Validated 5450/30305 images...
# ✓ Validated 5500/30305 images...
# ✓ Validated 5550/30305 images...
# ✓ Validated 5600/30305 images...
# ✓ Validated 5650/30305 images...
# ✓ Validated 5700/30305 images...
# ✓ Validated 5750/30305 images...
# ✓ Validated 5800/30305 images...
# ✓ Validated 5850/30305 images...
# ✓ Validated 5900/30305 images...
# ✓ Validated 5950/30305 images...
# ✓ Validated 6000/30305 images...
# ✓ Validated 6050/30305 images...
# ✓ Validated 6100/30305 images...
# ✓ Validated 6150/30305 images...
# ✓ Validated 6200/30305 images...
# ✓ Validated 6250/30305 images...
# ✓ Validated 6300/30305 images...
# ✓ Validated 6350/30305 images...
# ✓ Validated 6400/30305 images...
# ✓ Validated 6450/30305 images...
# ✓ Validated 6500/30305 images...
# ✓ Validated 6550/30305 images...
# ✓ Validated 6600/30305 images...
# ✓ Validated 6650/30305 images...
# ✓ Validated 6700/30305 images...
# ✓ Validated 6750/30305 images...
# ✓ Validated 6800/30305 images...
# ✓ Validated 6850/30305 images...
# ✓ Validated 6900/30305 images...
# ✓ Validated 6950/30305 images...
# ✓ Validated 7000/30305 images...
# ✓ Validated 7050/30305 images...
# ✓ Validated 7100/30305 images...
# ✓ Validated 7150/30305 images...
# ✓ Validated 7200/30305 images...
# ✓ Validated 7250/30305 images...
# ✓ Validated 7300/30305 images...
# ✓ Validated 7350/30305 images...
# ✓ Validated 7400/30305 images...
# ✓ Validated 7450/30305 images...
# ✓ Validated 7500/30305 images...
# ✓ Validated 7550/30305 images...
# ✓ Validated 7600/30305 images...
# ✓ Validated 7650/30305 images...
# ✓ Validated 7700/30305 images...
# ✓ Validated 7750/30305 images...
# ✓ Validated 7800/30305 images...
# ✓ Validated 7850/30305 images...
# ✓ Validated 7900/30305 images...
# ✓ Validated 7950/30305 images...
# ✓ Validated 8000/30305 images...
# ✓ Validated 8050/30305 images...
# ✓ Validated 8100/30305 images...
# ✓ Validated 8150/30305 images...
# ✓ Validated 8200/30305 images...
# ✓ Validated 8250/30305 images...
# ✓ Validated 8300/30305 images...
# ✓ Validated 8350/30305 images...
# ✓ Validated 8400/30305 images...
# ✓ Validated 8450/30305 images...
# ✓ Validated 8500/30305 images...
# ✓ Validated 8550/30305 images...
# ✓ Validated 8600/30305 images...
# ✓ Validated 8650/30305 images...
# ✓ Validated 8700/30305 images...
# ✓ Validated 8750/30305 images...
# ✓ Validated 8800/30305 images...
# ✓ Validated 8850/30305 images...
# ✓ Validated 8900/30305 images...
# ✓ Validated 8950/30305 images...
# ✓ Validated 9000/30305 images...
# ✓ Validated 9050/30305 images...
# ✓ Validated 9100/30305 images...
# ✓ Validated 9150/30305 images...
# ✓ Validated 9200/30305 images...
# ✓ Validated 9250/30305 images...
# ✓ Validated 9300/30305 images...
# ✓ Validated 9350/30305 images...
# ✓ Validated 9400/30305 images...
# ✓ Validated 9450/30305 images...
# ✓ Validated 9500/30305 images...
# ✓ Validated 9550/30305 images...
# ✓ Validated 9600/30305 images...
# ✓ Validated 9650/30305 images...
# ✓ Validated 9700/30305 images...
# ✓ Validated 9750/30305 images...
# ✓ Validated 9800/30305 images...
# ✓ Validated 9850/30305 images...
# ✓ Validated 9900/30305 images...
# ✓ Validated 9950/30305 images...
# ✓ Validated 10000/30305 images...
# ✓ Validated 10050/30305 images...
# ✓ Validated 10100/30305 images...
# ✓ Validated 10150/30305 images...
# ✓ Validated 10200/30305 images...
# ✓ Validated 10250/30305 images...
# ✓ Validated 10300/30305 images...
# ✓ Validated 10350/30305 images...
# ✓ Validated 10400/30305 images...
# ✓ Validated 10450/30305 images...
# ✓ Validated 10500/30305 images...
# ✓ Validated 10550/30305 images...
# ✓ Validated 10600/30305 images...
# ✓ Validated 10650/30305 images...
# ✓ Validated 10700/30305 images...
# ✓ Validated 10750/30305 images...
# ✓ Validated 10800/30305 images...
# ✓ Validated 10850/30305 images...
# ✓ Validated 10900/30305 images...
# ✓ Validated 10950/30305 images...
# ✓ Validated 11000/30305 images...
# ✓ Validated 11050/30305 images...
# ✓ Validated 11100/30305 images...
# ✓ Validated 11150/30305 images...
# ✓ Validated 11200/30305 images...
# ✓ Validated 11250/30305 images...
# ✓ Validated 11300/30305 images...
# ✓ Validated 11350/30305 images...
# ✓ Validated 11400/30305 images...
# ✓ Validated 11450/30305 images...
# ✓ Validated 11500/30305 images...
# ✓ Validated 11550/30305 images...
# ✓ Validated 11600/30305 images...
# ✓ Validated 11650/30305 images...
# ✓ Validated 11700/30305 images...
# ✓ Validated 11750/30305 images...
# ✓ Validated 11800/30305 images...
# ✓ Validated 11850/30305 images...
# ✓ Validated 11900/30305 images...
# ✓ Validated 11950/30305 images...
# ✓ Validated 12000/30305 images...
# ✓ Validated 12050/30305 images...
# ✓ Validated 12100/30305 images...
# ✓ Validated 12150/30305 images...
# ✓ Validated 12200/30305 images...
# ✓ Validated 12250/30305 images...
# ✓ Validated 12300/30305 images...
# ✓ Validated 12350/30305 images...
# ✓ Validated 12400/30305 images...
# ✓ Validated 12450/30305 images...
# ✓ Validated 12500/30305 images...
# ✓ Validated 12550/30305 images...
# ✓ Validated 12600/30305 images...
# ✓ Validated 12650/30305 images...
# ✓ Validated 12700/30305 images...
# ✓ Validated 12750/30305 images...
# ✓ Validated 12800/30305 images...
# ✓ Validated 12850/30305 images...
# ✓ Validated 12900/30305 images...
# ✓ Validated 12950/30305 images...
# ✓ Validated 13000/30305 images...
# ✓ Validated 13050/30305 images...
# ✓ Validated 13100/30305 images...
# ✓ Validated 13150/30305 images...
# ✓ Validated 13200/30305 images...
# ✓ Validated 13250/30305 images...
# ✓ Validated 13300/30305 images...
# ✓ Validated 13350/30305 images...
# ✓ Validated 13400/30305 images...
# ✓ Validated 13450/30305 images...
# ✓ Validated 13500/30305 images...
# ✓ Validated 13550/30305 images...
# ✓ Validated 13600/30305 images...
# ✓ Validated 13650/30305 images...
# ✓ Validated 13700/30305 images...
# ✓ Validated 13750/30305 images...
# ✓ Validated 13800/30305 images...
# ✓ Validated 13850/30305 images...
# ✓ Validated 13900/30305 images...
# ✓ Validated 13950/30305 images...
# ✓ Validated 14000/30305 images...
# ✓ Validated 14050/30305 images...
# ✓ Validated 14100/30305 images...
# ✓ Validated 14150/30305 images...
# ✓ Validated 14200/30305 images...
# ✓ Validated 14250/30305 images...
# ✓ Validated 14300/30305 images...
# ✓ Validated 14350/30305 images...
# ✓ Validated 14400/30305 images...
# ✓ Validated 14450/30305 images...
# ✓ Validated 14500/30305 images...
# ✓ Validated 14550/30305 images...
# ✓ Validated 14600/30305 images...
# ✓ Validated 14650/30305 images...
# ✓ Validated 14700/30305 images...
# ✓ Validated 14750/30305 images...
# ✓ Validated 14800/30305 images...
# ✓ Validated 14850/30305 images...
# ✓ Validated 14900/30305 images...
# ✓ Validated 14950/30305 images...
# ✓ Validated 15000/30305 images...
# ✓ Validated 15050/30305 images...
# ✓ Validated 15100/30305 images...
# ✓ Validated 15150/30305 images...
# ✓ Validated 15200/30305 images...
# ✓ Validated 15250/30305 images...
# ✓ Validated 15300/30305 images...
# ✓ Validated 15350/30305 images...
# ✓ Validated 15400/30305 images...
# ✓ Validated 15450/30305 images...
# ✓ Validated 15500/30305 images...
# ✓ Validated 15550/30305 images...
# ✓ Validated 15600/30305 images...
# ✓ Validated 15650/30305 images...
# ✓ Validated 15700/30305 images...
# ✓ Validated 15750/30305 images...
# ✓ Validated 15800/30305 images...
# ✓ Validated 15850/30305 images...
# ✓ Validated 15900/30305 images...
# ✓ Validated 15950/30305 images...
# ✓ Validated 16000/30305 images...
# ✓ Validated 16050/30305 images...
# ✓ Validated 16100/30305 images...
# ✓ Validated 16150/30305 images...
# ✓ Validated 16200/30305 images...
# ✓ Validated 16250/30305 images...
# ✓ Validated 16300/30305 images...
# ✓ Validated 16350/30305 images...
# ✓ Validated 16400/30305 images...
# ✓ Validated 16450/30305 images...
# ✓ Validated 16500/30305 images...
# ✓ Validated 16550/30305 images...
# ✓ Validated 16600/30305 images...
# ✓ Validated 16650/30305 images...
# ✓ Validated 16700/30305 images...
# ✓ Validated 16750/30305 images...
# ✓ Validated 16800/30305 images...
# ✓ Validated 16850/30305 images...
# ✓ Validated 16900/30305 images...
# ✓ Validated 16950/30305 images...
# ✓ Validated 17000/30305 images...
# ✓ Validated 17050/30305 images...
# ✓ Validated 17100/30305 images...
# ✓ Validated 17150/30305 images...
# ✓ Validated 17200/30305 images...
# ✓ Validated 17250/30305 images...
# ✓ Validated 17300/30305 images...
# ✓ Validated 17350/30305 images...
# ✓ Validated 17400/30305 images...
# ✓ Validated 17450/30305 images...
# ✓ Validated 17500/30305 images...
# ✓ Validated 17550/30305 images...
# ✓ Validated 17600/30305 images...
# ✓ Validated 17650/30305 images...
# ✓ Validated 17700/30305 images...
# ✓ Validated 17750/30305 images...
# ✓ Validated 17800/30305 images...
# ✓ Validated 17850/30305 images...
# ✓ Validated 17900/30305 images...
# ✓ Validated 17950/30305 images...
# ✓ Validated 18000/30305 images...
# ✓ Validated 18050/30305 images...
# ✓ Validated 18100/30305 images...
# ✓ Validated 18150/30305 images...
# ✓ Validated 18200/30305 images...
# ✓ Validated 18250/30305 images...
# ✓ Validated 18300/30305 images...
# ✓ Validated 18350/30305 images...
# ✓ Validated 18400/30305 images...
# ✓ Validated 18450/30305 images...
# ✓ Validated 18500/30305 images...
# ✓ Validated 18550/30305 images...
# ✓ Validated 18600/30305 images...
# ✓ Validated 18650/30305 images...
# ✓ Validated 18700/30305 images...
# ✓ Validated 18750/30305 images...
# ✓ Validated 18800/30305 images...
# ✓ Validated 18850/30305 images...
# ✓ Validated 18900/30305 images...
# ✓ Validated 18950/30305 images...
# ✓ Validated 19000/30305 images...
# ✓ Validated 19050/30305 images...
# ✓ Validated 19100/30305 images...
# ✓ Validated 19150/30305 images...
# ✓ Validated 19200/30305 images...
# ✓ Validated 19250/30305 images...
# ✓ Validated 19300/30305 images...
# ✓ Validated 19350/30305 images...
# ✓ Validated 19400/30305 images...
# ✓ Validated 19450/30305 images...
# ✓ Validated 19500/30305 images...
# ✓ Validated 19550/30305 images...
# ✓ Validated 19600/30305 images...
# ✓ Validated 19650/30305 images...
# ✓ Validated 19700/30305 images...
# ✓ Validated 19750/30305 images...
# ✓ Validated 19800/30305 images...
# ✓ Validated 19850/30305 images...
# ✓ Validated 19900/30305 images...
# ✓ Validated 19950/30305 images...
# ✓ Validated 20000/30305 images...
# ✓ Validated 20050/30305 images...
# ✓ Validated 20100/30305 images...
# ✓ Validated 20150/30305 images...
# ✓ Validated 20200/30305 images...
# ✓ Validated 20250/30305 images...
# ✓ Validated 20300/30305 images...
# ✓ Validated 20350/30305 images...
# ✓ Validated 20400/30305 images...
# ✓ Validated 20450/30305 images...
# ✓ Validated 20500/30305 images...
# ✓ Validated 20550/30305 images...
# ✓ Validated 20600/30305 images...
# ✓ Validated 20650/30305 images...
# ✓ Validated 20700/30305 images...
# ✓ Validated 20750/30305 images...
# ✓ Validated 20800/30305 images...
# ✓ Validated 20850/30305 images...
# ✓ Validated 20900/30305 images...
# ✓ Validated 20950/30305 images...
# ✓ Validated 21000/30305 images...
# ✓ Validated 21050/30305 images...
# ✓ Validated 21100/30305 images...
# ✓ Validated 21150/30305 images...
# ✓ Validated 21200/30305 images...
# ✓ Validated 21250/30305 images...
# ✓ Validated 21300/30305 images...
# ✓ Validated 21350/30305 images...
# ✓ Validated 21400/30305 images...
# ✓ Validated 21450/30305 images...
# ✓ Validated 21500/30305 images...
# ✓ Validated 21550/30305 images...
# ✓ Validated 21600/30305 images...
# ✓ Validated 21650/30305 images...
# ✓ Validated 21700/30305 images...
# ✓ Validated 21750/30305 images...
# ✓ Validated 21800/30305 images...
# ✓ Validated 21850/30305 images...
# ✓ Validated 21900/30305 images...
# ✓ Validated 21950/30305 images...
# ✓ Validated 22000/30305 images...
# ✓ Validated 22050/30305 images...
# ✓ Validated 22100/30305 images...
# ✓ Validated 22150/30305 images...
# ✓ Validated 22200/30305 images...
# ✓ Validated 22250/30305 images...
# ✓ Validated 22300/30305 images...
# ✓ Validated 22350/30305 images...
# ✓ Validated 22400/30305 images...
# ✓ Validated 22450/30305 images...
# ✓ Validated 22500/30305 images...
# ✓ Validated 22550/30305 images...
# ✓ Validated 22600/30305 images...
# ✓ Validated 22650/30305 images...
# ✓ Validated 22700/30305 images...
# ✓ Validated 22750/30305 images...
# ✓ Validated 22800/30305 images...
# ✓ Validated 22850/30305 images...
# ✓ Validated 22900/30305 images...
# ✓ Validated 22950/30305 images...
# ✓ Validated 23000/30305 images...
# ✓ Validated 23050/30305 images...
# ✓ Validated 23100/30305 images...
# ✓ Validated 23150/30305 images...
# ✓ Validated 23200/30305 images...
# ✓ Validated 23250/30305 images...
# ✓ Validated 23300/30305 images...
# ✓ Validated 23350/30305 images...
# ✓ Validated 23400/30305 images...
# ✓ Validated 23450/30305 images...
# ✓ Validated 23500/30305 images...
# ✓ Validated 23550/30305 images...
# ✓ Validated 23600/30305 images...
# ✓ Validated 23650/30305 images...
# ✓ Validated 23700/30305 images...
# ✓ Validated 23750/30305 images...
# ✓ Validated 23800/30305 images...
# ✓ Validated 23850/30305 images...
# ✓ Validated 23900/30305 images...
# ✓ Validated 23950/30305 images...
# ✓ Validated 24000/30305 images...
# ✓ Validated 24050/30305 images...
# ✓ Validated 24100/30305 images...
# ✓ Validated 24150/30305 images...
# ✓ Validated 24200/30305 images...
# ✓ Validated 24250/30305 images...
# ✓ Validated 24300/30305 images...
# ✓ Validated 24350/30305 images...
# ✓ Validated 24400/30305 images...
# ✓ Validated 24450/30305 images...
# ✓ Validated 24500/30305 images...
# ✓ Validated 24550/30305 images...
# ✓ Validated 24600/30305 images...
# ✓ Validated 24650/30305 images...
# ✓ Validated 24700/30305 images...
# ✓ Validated 24750/30305 images...
# ✓ Validated 24800/30305 images...
# ✓ Validated 24850/30305 images...
# ✓ Validated 24900/30305 images...
# ✓ Validated 24950/30305 images...
# ✓ Validated 25000/30305 images...
# ✓ Validated 25050/30305 images...
# ✓ Validated 25100/30305 images...
# ✓ Validated 25150/30305 images...
# ✓ Validated 25200/30305 images...
# ✓ Validated 25250/30305 images...
# ✓ Validated 25300/30305 images...
# ✓ Validated 25350/30305 images...
# ✓ Validated 25400/30305 images...
# ✓ Validated 25450/30305 images...
# ✓ Validated 25500/30305 images...
# ✓ Validated 25550/30305 images...
# ✓ Validated 25600/30305 images...
# ✓ Validated 25650/30305 images...
# ✓ Validated 25700/30305 images...
# ✓ Validated 25750/30305 images...
# ✓ Validated 25800/30305 images...
# ✓ Validated 25850/30305 images...
# ✓ Validated 25900/30305 images...
# ✓ Validated 25950/30305 images...
# ✓ Validated 26000/30305 images...
# ✓ Validated 26050/30305 images...
# ✓ Validated 26100/30305 images...
# ✓ Validated 26150/30305 images...
# ✓ Validated 26200/30305 images...
# ✓ Validated 26250/30305 images...
# ✓ Validated 26300/30305 images...
# ✓ Validated 26350/30305 images...
# ✓ Validated 26400/30305 images...
# ✓ Validated 26450/30305 images...
# ✓ Validated 26500/30305 images...
# ✓ Validated 26550/30305 images...
# ✓ Validated 26600/30305 images...
# ✓ Validated 26650/30305 images...
# ✓ Validated 26700/30305 images...
# ✓ Validated 26750/30305 images...
# ✓ Validated 26800/30305 images...
# ✓ Validated 26850/30305 images...
# ✓ Validated 26900/30305 images...
# ✓ Validated 26950/30305 images...
# ✓ Validated 27000/30305 images...
# ✓ Validated 27050/30305 images...
# ✓ Validated 27100/30305 images...
# ✓ Validated 27150/30305 images...
# ✓ Validated 27200/30305 images...
# ✓ Validated 27250/30305 images...
# ✓ Validated 27300/30305 images...
# ✓ Validated 27350/30305 images...
# ✓ Validated 27400/30305 images...
# ✓ Validated 27450/30305 images...
# ✓ Validated 27500/30305 images...
# ✓ Validated 27550/30305 images...
# ✓ Validated 27600/30305 images...
# ✓ Validated 27650/30305 images...
# ✓ Validated 27700/30305 images...
# ✓ Validated 27750/30305 images...
# ✓ Validated 27800/30305 images...
# ✓ Validated 27850/30305 images...
# ✓ Validated 27900/30305 images...
# ✓ Validated 27950/30305 images...
# ✓ Validated 28000/30305 images...
# ✓ Validated 28050/30305 images...
# ✓ Validated 28100/30305 images...
# ✓ Validated 28150/30305 images...
# ✓ Validated 28200/30305 images...
# ✓ Validated 28250/30305 images...
# ✓ Validated 28300/30305 images...
# ✓ Validated 28350/30305 images...
# ✓ Validated 28400/30305 images...
# ✓ Validated 28450/30305 images...
# ✓ Validated 28500/30305 images...
# ✓ Validated 28550/30305 images...
# ✓ Validated 28600/30305 images...
# ✓ Validated 28650/30305 images...
# ✓ Validated 28700/30305 images...
# ✓ Validated 28750/30305 images...
# ✓ Validated 28800/30305 images...
# ✓ Validated 28850/30305 images...
# ✓ Validated 28900/30305 images...
# ✓ Validated 28950/30305 images...
# ✓ Validated 29000/30305 images...
# ✓ Validated 29050/30305 images...
# ✓ Validated 29100/30305 images...
# ✓ Validated 29150/30305 images...
# ✓ Validated 29200/30305 images...
# ✓ Validated 29250/30305 images...
# ✓ Validated 29300/30305 images...
# ✓ Validated 29350/30305 images...
# ✓ Validated 29400/30305 images...
# ✓ Validated 29450/30305 images...
# ✓ Validated 29500/30305 images...
# ✓ Validated 29550/30305 images...
# ✓ Validated 29600/30305 images...
# ✓ Validated 29650/30305 images...
# ✓ Validated 29700/30305 images...
# ✓ Validated 29750/30305 images...
# ✓ Validated 29800/30305 images...
# ✓ Validated 29850/30305 images...
# ✓ Validated 29900/30305 images...
# ✓ Validated 29950/30305 images...
# ✓ Validated 30000/30305 images...
# ✓ Validated 30050/30305 images...
# ✓ Validated 30100/30305 images...
# ✓ Validated 30150/30305 images...
# ✓ Validated 30200/30305 images...
# ✓ Validated 30250/30305 images...
# ✓ Validated 30300/30305 images...
#
# ✓ TensorFlow validation complete!
#   - Valid images: 30305
#   - Removed: 0
#
# Validating with TensorFlow: data/test
# Found 17 image files to check
#
# ✓ TensorFlow validation complete!
#   - Valid images: 17
#   - Removed: 0
# []

# %%
# load datasets
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=False
)

class_names = train_ds.class_names
num_classes = len(class_names)
print("\nClasses found:", class_names)
print(f"Number of classes: {num_classes}")
# Out:
# Found 30305 files belonging to 3 classes.
# Found 17 files belonging to 2 classes.
#
# Classes found: ['galaxy', 'nebulai', 'star']
# Number of classes: 3

# %%
train_ds = train_ds.cache().prefetch(tf.data.AUTOTUNE)
test_ds = test_ds.cache().prefetch(tf.data.AUTOTUNE)

# %%
# Build models
model = models.Sequential([
    layers.Rescaling(1./255, input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    layers.Conv2D(16, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print(model.summary())
# Out:
# C:\Users\samriti\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\preprocessing\data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 64, 64, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 62, 62, 16)          │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 31, 31, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 29, 29, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 12, 12, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 6, 6, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2304)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │         147,520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 171,299 (669.14 KB)
#  Trainable params: 171,299 (669.14 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# training
history = model.fit(
    train_ds, 
    validation_data=test_ds, 
    epochs=EPOCHS
)
# Out:
# Epoch 1/5
# 1895/1895 ━━━━━━━━━━━━━━━━━━━━ 102s 50ms/step - accuracy: 0.9902 - loss: 0.0411 - val_accuracy: 1.0000 - val_loss: 0.1330
# Epoch 2/5
# 1895/1895 ━━━━━━━━━━━━━━━━━━━━ 80s 42ms/step - accuracy: 0.9960 - loss: 0.0168 - val_accuracy: 1.0000 - val_loss: 0.1689
# Epoch 3/5
# 1895/1895 ━━━━━━━━━━━━━━━━━━━━ 78s 41ms/step - accuracy: 0.9964 - loss: 0.0139 - val_accuracy: 1.0000 - val_loss: 0.1581
# Epoch 4/5
# 1895/1895 ━━━━━━━━━━━━━━━━━━━━ 80s 42ms/step - accuracy: 0.9970 - loss: 0.0115 - val_accuracy: 0.9412 - val_loss: 0.2668
# Epoch 5/5
# 1895/1895 ━━━━━━━━━━━━━━━━━━━━ 78s 41ms/step - accuracy: 0.9972 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.2580

# %%
# evaluation
test_loss, test_acc = model.evaluate(test_ds)
print(f"\nBaseline Test Accuracy: {round(test_acc * 100, 2)}%")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.2580
#
# Baseline Test Accuracy: 100.0%

# %%
import numpy as np
y_true = []
y_pred = []

for images, labels in test_ds:
    preds = model.predict(images, verbose=0)
    pred_classes = np.argmax(preds, axis=1)
    y_true.extend(labels.numpy())
    y_pred.extend(pred_classes)

y_true = np.array(y_true)
y_pred = np.array(y_pred)

print("Model Performance Summary:")

overall_acc = (y_true == y_pred).sum() / len(y_true)
print(f"\nOverall Accuracy: {overall_acc * 100:.2f}%")

print(f"\nTotal samples: {len(y_true)}")

for i, class_name in enumerate(class_names):
    # Get samples for this class
    true_mask = y_true == i
    num_samples = true_mask.sum()
    
    if num_samples > 0:
        # Calculate accuracy for this class
        correct = ((y_true == i) & (y_pred == i)).sum()
        accuracy = correct / num_samples * 100
        
        print(f"\n{class_name}:")
        print(f"  Samples: {num_samples}")
        print(f"  Correct: {correct}")
        print(f"  Accuracy: {accuracy:.2f}%")

gc.collect()
# Out:
# ============================================================
# Model Performance Summary:
# ============================================================
#
# Overall Accuracy: 100.00%
#
# Total samples: 17
#
# nebulai:
#   Samples: 17
#   Correct: 17
#   Accuracy: 100.00%
# 609

# %%
os.makedirs("results", exist_ok=True)

# Save a simpler report
with open("results/baseline_performance.txt", "w") as f:
    f.write("BASELINE MODEL PERFORMANCE\n")
    
    f.write(f"Test Accuracy: {round(test_acc * 100, 2)}%\n")
    f.write(f"Test Loss: {round(test_loss, 4)}\n\n")
    
    f.write("Classes:\n")
    for i, c in enumerate(class_names):
        f.write(f"  {i}: {c}\n")
    
    f.write("\n" + "=" * 60 + "\n")
    f.write("PER-CLASS PERFORMANCE\n")
    f.write("=" * 60 + "\n\n")
    
    # Manual per-class accuracy
    for i, class_name in enumerate(class_names):
        class_mask = y_true == i
        if class_mask.sum() > 0:
            correct = ((y_true == i) & (y_pred == i)).sum()
            total = class_mask.sum()
            accuracy = correct / total * 100
            f.write(f"{class_name}:\n")
            f.write(f"  Samples: {total}\n")
            f.write(f"  Correct: {correct}\n")
            f.write(f"  Accuracy: {accuracy:.2f}%\n\n")
    
    f.write("CONFIGURATION\n")
    f.write(f"Image Size: {IMG_SIZE}x{IMG_SIZE}\n")
    f.write(f"Batch Size: {BATCH_SIZE}\n")
    f.write(f"Epochs: {EPOCHS}\n")

print("Performance report saved")

# Save model
model.save("results/baseline_model.h5")
print("Model saved")

gc.collect()
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✓ Performance report saved
# ✓ Model saved as .h5
# 0
